# %% [markdown]
# # Variables hold values, just like in algebra

# %%
x = 3 * 2
print (x)

# %%
M2 = 0.5
V1 = 0.3
V2 = 2.5

# calculate M1 (remember:  M1V1 = M2V2)

# %% [markdown]
# Use ** for powers

# %%
print (2**3)

# %% [markdown]
# variables can hold lists of items (vectors)

# %%
x_list = [1,2,3,4]
print (x_list)

# %% [markdown]
# you can do an operation on each element on a list with the for keyword

# %%
for x in x_list:
	print (x**2)

# %% [markdown]
# Python allows you to easily use other people's code ("libraries")

# %%
# %pip install qrcode
import qrcode

# %%
img = qrcode.make("You just made a QR code!")
img
